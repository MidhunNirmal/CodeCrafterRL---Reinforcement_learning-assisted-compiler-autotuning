# %%
import pandas as pd
import os

def inspect_data():
    """Inspect the data.csv file to understand its structure"""
    data_path = "C:/Users/sis/Desktop/mini1 - Copy/alternatedata/raw_data/data.csv"
    
    if not os.path.exists(data_path):
        print(f"Error: File not found at {data_path}")
        return
    
    # Load the data
    print("="*80)
    print("DATA INSPECTION")
    print("="*80)
    
    df = pd.read_csv(data_path)
    
    print(f"Dataset shape: {df.shape}")
    print(f"Total rows: {len(df)}")
    print(f"Total columns: {len(df.columns)}")
    
    print(f"\n" + "="*80)
    print("ALL COLUMN NAMES")
    print("="*80)
    
    for i, col in enumerate(df.columns):
        print(f"{i+1:3d}. {col}")
    
    print(f"\n" + "="*80)
    print("COLUMN TYPES")
    print("="*80)
    
    print(df.dtypes.value_counts())
    
    print(f"\n" + "="*80)
    print("FIRST 10 COLUMNS DETAILED")
    print("="*80)
    
    for i, col in enumerate(df.columns[:10]):
        print(f"\n{i+1}. {col}")
        print(f"   Type: {df[col].dtype}")
        print(f"   Unique values: {df[col].nunique()}")
        print(f"   Sample values: {list(df[col].unique()[:5])}")
    
    print(f"\n" + "="*80)
    print("LAST 10 COLUMNS DETAILED")
    print("="*80)
    
    for i, col in enumerate(df.columns[-10:]):
        print(f"\n{len(df.columns)-9+i}. {col}")
        print(f"   Type: {df[col].dtype}")
        print(f"   Unique values: {df[col].nunique()}")
        if df[col].dtype in ['int64', 'float64']:
            print(f"   Min: {df[col].min()}")
            print(f"   Max: {df[col].max()}")
            print(f"   Mean: {df[col].mean():.2f}")
    
    print(f"\n" + "="*80)
    print("BENCHMARK ANALYSIS")
    print("="*80)
    
    if 'APP_NAME' in df.columns:
        benchmarks = df['APP_NAME'].value_counts()
        print(f"Total benchmarks: {len(benchmarks)}")
        print(f"Benchmarks:")
        for bench, count in benchmarks.items():
            print(f"  {bench}: {count} samples")
    
    print(f"\n" + "="*80)
    print("SUMMARY")
    print("="*80)
    print(f"✅ Total columns: {len(df.columns)}")
    print(f"✅ Total samples: {len(df)}")
    print(f"✅ Column types: {dict(df.dtypes.value_counts())}")
    print(f"✅ Ready for analysis!")

if __name__ == "__main__":
    inspect_data()
# Out:
# ================================================================================
# DATA INSPECTION
# ================================================================================
# Dataset shape: (3072, 292)
# Total rows: 3072
# Total columns: 292
#
# ================================================================================
# ALL COLUMN NAMES
# ================================================================================
#   1. APP_NAME
#   2. funsafe_math_optimizations
#   3. fno_guess_branch_probability
#   4. fno_ivopts
#   5. fno_tree_loop_optimize
#   6. fno_inline_functions
#   7. funroll_all_loops
#   8. o2
#   9. code_size
#  10. noBasicBlock
#  11. nobasicBlockSingleSocc
#  12. nobasicBlock2Socc
#  13. noBasicBlockSoccMore
#  14. noBasicBlockPred
#  15. noBasicBlock2Pred
#  16. noBasicBlockPredMore
#  17. ft8
#  18. ft9
#  19. ft10
#  20. ft11
#  21. ft12
#  22. ft13
#  23. ft14
#  24. ft15
#  25. ft16
#  26. ft17
#  27. ft19
#  28. ft20
#  29. ft21
#  30. ft22
#  31. ft23
#  32. ft24
#  33. ft25
#  34. ft26
#  35. ft27
#  36. ft28
#  37. ft29
#  38. ft30
#  39. ft31
#  40. ft33
#  41. ft34
#  42. ft35
#  43. ft36
#  44. ft37
#  45. ft38
#  46. ft39
#  47. ft40
#  48. ft41
#  49. ft42
#  50. ft43
#  51. ft44
#  52. ft45
#  53. ft46
#  54. ft47
#  55. ft48
#  56. ft49
#  57. ft50
#  58. ft51
#  59. ft52
#  60. ft53
#  61. ft54
#  62. ft55
#  63. ILP32_1
#  64. arithmetic_1
#  65. InstrFootprint64_1
#  66. DataFootprint64_1
#  67. mem_access_1
#  68. memReuseDist0-2_1
#  69. memReuseDist2-4_1
#  70. memReuseDist4-8_1
#  71. memReuseDist8-16_1
#  72. GAg_mispred_cnt_4bits_1
#  73. PAg_mispred_cnt_4bits_1
#  74. GAs_mispred_cnt_4bits_1
#  75. PAs_mispred_cnt_4bits_1
#  76. GAg_mispred_cnt_8bits_1
#  77. PAg_mispred_cnt_8bits_1
#  78. GAs_mispred_cnt_8bits_1
#  79. PAs_mispred_cnt_8bits_1
#  80. GAg_mispred_cnt_12bits_1
#  81. PAg_mispred_cnt_12bits_1
#  82. GAs_mispred_cnt_12bits_1
#  83. PAs_mispred_cnt_12bits_1
#  84. total_brCount_1
#  85. total_transactionCount_1
#  86. total_takenCount_1
#  87. total_num_ops_1
#  88. instr_reg_cnt_1
#  89. total_reg_use_cnt_1
#  90. total_reg_age_1
#  91. reg_age_cnt_1_1
#  92. reg_age_cnt_2_1
#  93. reg_age_cnt_4_1
#  94. reg_age_cnt_8_1
#  95. mem_read_cnt_1
#  96. mem_read_local_stride_0_1
#  97. mem_read_local_stride_8_1
#  98. mem_read_global_stride_0_1
#  99. mem_read_global_stride_8_1
# 100. mem_write_cnt_1
# 101. mem_write_local_stride_0_1
# 102. mem_write_local_stride_8_1
# 103. mem_write_global_stride_0_1
# 104. mem_write_global_stride_8_1
# 105. mem_write_global_stride_64_1
# 106. mem_write_global_stride_512_1
# 107. mem_write_global_stride_4096_1
# 108. ILP32_2
# 109. arithmetic_2
# 110. InstrFootprint64_2
# 111. DataFootprint64_2
# 112. mem_access_2
# 113. memReuseDist0-2_2
# 114. memReuseDist2-4_2
# 115. memReuseDist4-8_2
# 116. memReuseDist8-16_2
# 117. GAg_mispred_cnt_4bits_2
# 118. PAg_mispred_cnt_4bits_2
# 119. GAs_mispred_cnt_4bits_2
# 120. PAs_mispred_cnt_4bits_2
# 121. GAg_mispred_cnt_8bits_2
# 122. PAg_mispred_cnt_8bits_2
# 123. GAs_mispred_cnt_8bits_2
# 124. PAs_mispred_cnt_8bits_2
# 125. GAg_mispred_cnt_12bits_2
# 126. PAg_mispred_cnt_12bits_2
# 127. GAs_mispred_cnt_12bits_2
# 128. PAs_mispred_cnt_12bits_2
# 129. total_brCount_2
# 130. total_transactionCount_2
# 131. total_takenCount_2
# 132. total_num_ops_2
# 133. instr_reg_cnt_2
# 134. total_reg_use_cnt_2
# 135. total_reg_age_2
# 136. reg_age_cnt_1_2
# 137. reg_age_cnt_2_2
# 138. reg_age_cnt_4_2
# 139. reg_age_cnt_8_2
# 140. mem_read_cnt_2
# 141. mem_read_local_stride_0_2
# 142. mem_read_local_stride_8_2
# 143. mem_read_global_stride_0_2
# 144. mem_read_global_stride_8_2
# 145. mem_write_cnt_2
# 146. mem_write_local_stride_0_2
# 147. mem_write_local_stride_8_2
# 148. mem_write_global_stride_0_2
# 149. mem_write_global_stride_8_2
# 150. mem_write_global_stride_64_2
# 151. mem_write_global_stride_512_2
# 152. mem_write_global_stride_4096_2
# 153. ILP32_3
# 154. arithmetic_3
# 155. InstrFootprint64_3
# 156. DataFootprint64_3
# 157. mem_access_3
# 158. memReuseDist0-2_3
# 159. memReuseDist2-4_3
# 160. memReuseDist4-8_3
# 161. memReuseDist8-16_3
# 162. GAg_mispred_cnt_4bits_3
# 163. PAg_mispred_cnt_4bits_3
# 164. GAs_mispred_cnt_4bits_3
# 165. PAs_mispred_cnt_4bits_3
# 166. GAg_mispred_cnt_8bits_3
# 167. PAg_mispred_cnt_8bits_3
# 168. GAs_mispred_cnt_8bits_3
# 169. PAs_mispred_cnt_8bits_3
# 170. GAg_mispred_cnt_12bits_3
# 171. PAg_mispred_cnt_12bits_3
# 172. GAs_mispred_cnt_12bits_3
# 173. PAs_mispred_cnt_12bits_3
# 174. total_brCount_3
# 175. total_transactionCount_3
# 176. total_takenCount_3
# 177. total_num_ops_3
# 178. instr_reg_cnt_3
# 179. total_reg_use_cnt_3
# 180. total_reg_age_3
# 181. reg_age_cnt_1_3
# 182. reg_age_cnt_2_3
# 183. reg_age_cnt_4_3
# 184. reg_age_cnt_8_3
# 185. mem_read_cnt_3
# 186. mem_read_local_stride_0_3
# 187. mem_read_local_stride_8_3
# 188. mem_read_global_stride_0_3
# 189. mem_read_global_stride_8_3
# 190. mem_write_cnt_3
# 191. mem_write_local_stride_0_3
# 192. mem_write_local_stride_8_3
# 193. mem_write_global_stride_0_3
# 194. mem_write_global_stride_8_3
# 195. mem_write_global_stride_64_3
# 196. mem_write_global_stride_512_3
# 197. mem_write_global_stride_4096_3
# 198. ILP32_4
# 199. arithmetic_4
# 200. InstrFootprint64_4
# 201. DataFootprint64_4
# 202. mem_access_4
# 203. memReuseDist0-2_4
# 204. memReuseDist2-4_4
# 205. memReuseDist4-8_4
# 206. memReuseDist8-16_4
# 207. GAg_mispred_cnt_4bits_4
# 208. PAg_mispred_cnt_4bits_4
# 209. GAs_mispred_cnt_4bits_4
# 210. PAs_mispred_cnt_4bits_4
# 211. GAg_mispred_cnt_8bits_4
# 212. PAg_mispred_cnt_8bits_4
# 213. GAs_mispred_cnt_8bits_4
# 214. PAs_mispred_cnt_8bits_4
# 215. GAg_mispred_cnt_12bits_4
# 216. PAg_mispred_cnt_12bits_4
# 217. GAs_mispred_cnt_12bits_4
# 218. PAs_mispred_cnt_12bits_4
# 219. total_brCount_4
# 220. total_transactionCount_4
# 221. total_takenCount_4
# 222. total_num_ops_4
# 223. instr_reg_cnt_4
# 224. total_reg_use_cnt_4
# 225. total_reg_age_4
# 226. reg_age_cnt_1_4
# 227. reg_age_cnt_2_4
# 228. reg_age_cnt_4_4
# 229. reg_age_cnt_8_4
# 230. mem_read_cnt_4
# 231. mem_read_local_stride_0_4
# 232. mem_read_local_stride_8_4
# 233. mem_read_global_stride_0_4
# 234. mem_read_global_stride_8_4
# 235. mem_write_cnt_4
# 236. mem_write_local_stride_0_4
# 237. mem_write_local_stride_8_4
# 238. mem_write_global_stride_0_4
# 239. mem_write_global_stride_8_4
# 240. mem_write_global_stride_64_4
# 241. mem_write_global_stride_512_4
# 242. mem_write_global_stride_4096_4
# 243. ILP32_5
# 244. arithmetic_5
# 245. InstrFootprint64_5
# 246. DataFootprint64_5
# 247. mem_access_5
# 248. memReuseDist0-2_5
# 249. memReuseDist2-4_5
# 250. memReuseDist4-8_5
# 251. memReuseDist8-16_5
# 252. GAg_mispred_cnt_4bits_5
# 253. PAg_mispred_cnt_4bits_5
# 254. GAs_mispred_cnt_4bits_5
# 255. PAs_mispred_cnt_4bits_5
# 256. GAg_mispred_cnt_8bits_5
# 257. PAg_mispred_cnt_8bits_5
# 258. GAs_mispred_cnt_8bits_5
# 259. PAs_mispred_cnt_8bits_5
# 260. GAg_mispred_cnt_12bits_5
# 261. PAg_mispred_cnt_12bits_5
# 262. GAs_mispred_cnt_12bits_5
# 263. PAs_mispred_cnt_12bits_5
# 264. total_brCount_5
# 265. total_transactionCount_5
# 266. total_takenCount_5
# 267. total_num_ops_5
# 268. instr_reg_cnt_5
# 269. total_reg_use_cnt_5
# 270. total_reg_age_5
# 271. reg_age_cnt_1_5
# 272. reg_age_cnt_2_5
# 273. reg_age_cnt_4_5
# 274. reg_age_cnt_8_5
# 275. mem_read_cnt_5
# 276. mem_read_local_stride_0_5
# 277. mem_read_local_stride_8_5
# 278. mem_read_global_stride_0_5
# 279. mem_read_global_stride_8_5
# 280. mem_write_cnt_5
# 281. mem_write_local_stride_0_5
# 282. mem_write_local_stride_8_5
# 283. mem_write_global_stride_0_5
# 284. mem_write_global_stride_8_5
# 285. mem_write_global_stride_64_5
# 286. mem_write_global_stride_512_5
# 287. mem_write_global_stride_4096_5
# 288. execution_time_1
# 289. execution_time_2
# 290. execution_time_3
# 291. execution_time_4
# 292. execution_time_5
#
# ================================================================================
# COLUMN TYPES
# ================================================================================
# int64      283
# float64      8
# object       1
# Name: count, dtype: int64
#
# ================================================================================
# FIRST 10 COLUMNS DETAILED
# ================================================================================
#
# 1. APP_NAME
#    Type: object
#    Unique values: 24
#    Sample values: ['automotive_bitcount', 'automotive_qsort1', 'automotive_susan_c', 'automotive_susan_e', 'automotive_susan_s']
#
# 2. funsafe_math_optimizations
#    Type: int64
#    Unique values: 2
#    Sample values: [0, 1]
#
# 3. fno_guess_branch_probability
#    Type: int64
#    Unique values: 2
#    Sample values: [0, 1]
#
# 4. fno_ivopts
#    Type: int64
#    Unique values: 2
#    Sample values: [0, 1]
#
# 5. fno_tree_loop_optimize
#    Type: int64
#    Unique values: 2
#    Sample values: [0, 1]
#
# 6. fno_inline_functions
#    Type: int64
#    Unique values: 2
#    Sample values: [0, 1]
#
# 7. funroll_all_loops
#    Type: int64
#    Unique values: 2
#    Sample values: [0, 1]
#
# 8. o2
#    Type: int64
#    Unique values: 2
#    Sample values: [0, 1]
#
# 9. code_size
#    Type: int64
#    Unique values: 444
#    Sample values: [457478, 461574, 461606, 469741, 473837]
#
# 10. noBasicBlock
#    Type: int64
#    Unique values: 17
#    Sample values: [129, 85, 628, 132, 146]
#
# ================================================================================
# LAST 10 COLUMNS DETAILED
# ================================================================================
#
# 283. mem_write_global_stride_0_5
#    Type: int64
#    Unique values: 9
#    Min: 2
#    Max: 1355
#    Mean: 95.17
#
# 284. mem_write_global_stride_8_5
#    Type: int64
#    Unique values: 23
#    Min: 3630
#    Max: 10782584
#    Mean: 1461355.33
#
# 285. mem_write_global_stride_64_5
#    Type: int64
#    Unique values: 23
#    Min: 122712
#    Max: 71760056
#    Mean: 5655655.83
#
# 286. mem_write_global_stride_512_5
#    Type: int64
#    Unique values: 23
#    Min: 142648
#    Max: 71761599
#    Mean: 6252587.00
#
# 287. mem_write_global_stride_4096_5
#    Type: int64
#    Unique values: 23
#    Min: 158223
#    Max: 71761792
#    Mean: 6318930.29
#
# 288. execution_time_1
#    Type: float64
#    Unique values: 2822
#    Min: 8.86027
#    Max: 6651.31
#    Mean: 659.94
#
# 289. execution_time_2
#    Type: float64
#    Unique values: 2933
#    Min: 12.5326
#    Max: 7147.79
#    Mean: 844.97
#
# 290. execution_time_3
#    Type: float64
#    Unique values: 2999
#    Min: 14.6077
#    Max: 18179.5
#    Mean: 3204.56
#
# 291. execution_time_4
#    Type: float64
#    Unique values: 3021
#    Min: 17.7205
#    Max: 8122.07
#    Mean: 1406.95
#
# 292. execution_time_5
#    Type: float64
#    Unique values: 2920
#    Min: 21.5047
#    Max: 15559.9
#    Mean: 993.34
#
# ================================================================================
# BENCHMARK ANALYSIS
# ================================================================================
# Total benchmarks: 24
# Benchmarks:
#   automotive_bitcount: 128 samples
#   automotive_qsort1: 128 samples
#   bzip2d: 128 samples
#   office_stringsearch1: 128 samples
#   network_patricia: 128 samples
#   network_dijkstra: 128 samples
#   consumer_tiffmedian: 128 samples
#   consumer_tiffdither: 128 samples
#   consumer_tiff2rgba: 128 samples
#   consumer_tiff2bw: 128 samples
#   consumer_jpeg_d: 128 samples
#   consumer_jpeg_c: 128 samples
#   telecom_CRC32: 128 samples
#   telecom_adpcm_d: 128 samples
#   telecom_adpcm_c: 128 samples
#   security_sha: 128 samples
#   security_rijndael_e: 128 samples
#   security_rijndael_d: 128 samples
#   security_blowfish_e: 128 samples
#   security_blowfish_d: 128 samples
#   automotive_susan_s: 128 samples
#   automotive_susan_e: 128 samples
#   automotive_susan_c: 128 samples
#   bzip2e: 128 samples
#
# ================================================================================
# SUMMARY
# ================================================================================
# ✅ Total columns: 292
# ✅ Total samples: 3072
# ✅ Column types: {dtype('int64'): 283, dtype('float64'): 8, dtype('O'): 1}
# ✅ Ready for analysis!
